# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Init-data" data-toc-modified-id="Init-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Init data</a></span><ul class="toc-item"><li><span><a href="#Estaciones" data-toc-modified-id="Estaciones-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Estaciones</a></span></li><li><span><a href="#Data-Mediciones" data-toc-modified-id="Data-Mediciones-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Data Mediciones</a></span></li></ul></li><li><span><a href="#Predicción-de-Ozono-para-el-Valle-de-México" data-toc-modified-id="Predicción-de-Ozono-para-el-Valle-de-México-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Predicción de Ozono para el Valle de México</a></span><ul class="toc-item"><li><span><a href="#Por-estacion" data-toc-modified-id="Por-estacion-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Por estacion</a></span></li><li><span><a href="#Para-el-Valle-de-México-por-hora" data-toc-modified-id="Para-el-Valle-de-México-por-hora-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Para el Valle de México por hora</a></span></li><li><span><a href="#Valle-de-México-por-día" data-toc-modified-id="Valle-de-México-por-día-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Valle de México por día</a></span></li></ul></li><li><span><a href="#Predicción-de-Ozono-para-Guadalajara" data-toc-modified-id="Predicción-de-Ozono-para-Guadalajara-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Predicción de Ozono para Guadalajara</a></span><ul class="toc-item"><li><span><a href="#Para-GDL-por-hora" data-toc-modified-id="Para-GDL-por-hora-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Para GDL por hora</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
from joblib import Parallel, delayed
import numpy as np
import json
from pathlib import Path
import altair as alt
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
import matplotlib as mpl
import mplleaflet

from fbprophet import Prophet

pd.options.mode.chained_assignment = None

# %matplotlib inline

# %% [markdown]
# # Init data

# %% [markdown]
# ## Estaciones

# %%
estaciones = pd.read_csv('/data/calidad_aire_presidencia/data_estaciones_sinaica.csv')
mask = (estaciones.lat.between(14, 34.5)) & (estaciones.long.between(-120, -70))
estaciones = estaciones[mask].rename(columns={'id':'estacionesid'})

print(estaciones.shape)
estaciones.head()
# Out:
# (180, 8)
#                         _id        lat        long  estacionesid  \
# 0  5b8850e3e2705c1932e82ff8  21.873311 -102.320803            31
# 1  5b8850e3e2705c1932e82ff9  21.846392 -102.288431            32
# 2  5b8850e3e2705c1932e82ffa  21.883781 -102.295825            33
# 3  5b8850e3e2705c1932e82ffb  31.859917 -116.593722            36
# 4  5b8850e3e2705c1932e82ffc  32.631317 -115.444631            38
#
#                          nombre   codigo  redesid              date-insert
# 0                        CBTIS       CBT       30  2018-08-30 20:17:39.218
# 1  Secretaría de Medio Ambiente      SMA       30  2018-08-30 20:17:39.218
# 2                        Centro      CEN       30  2018-08-30 20:17:39.218
# 3                    Secundaria  SPABC20       31  2018-08-30 20:17:39.218
# 4                          UABC  SPABC12       32  2018-08-30 20:17:39.218

# %% [markdown]
# ## Data Mediciones

# %%
mediciones = pd.read_csv('/data/calidad_aire_presidencia/data_mediciones_todas_estaciones_2.csv')
print(mediciones.shape)
mediciones.head()
# Out:
# (3240000, 8)
#       city  estacionesid       fecha  hora parametro    state  validoorig  \
# 0  Durango            58  2018-08-01    13      PM10  Durango           1
# 1  Durango            58  2018-08-01    14      PM10  Durango           1
# 2  Durango            58  2018-08-01    15      PM10  Durango           1
# 3  Durango            58  2018-08-01    16      PM10  Durango           1
# 4  Durango            58  2018-08-01    17      PM10  Durango           1
#
#    valororig
# 0     988.61
# 1     988.61
# 2     988.60
# 3     988.63
# 4     988.63

# %%
estaciones_ciudad = mediciones[['city', 'state', 'estacionesid']].drop_duplicates()
print(estaciones_ciudad.shape)
estaciones_ciudad.head()
# Out:
# (123, 3)
#                 city       state  estacionesid
# 0            Durango     Durango            58
# 6543         Durango     Durango            59
# 33554        Durango     Durango            60
# 65683  Gómez Palacio     Durango            65
# 80484         Celaya  Guanajuato            68

# %%
estaciones_ciudad.groupby('city').estacionesid.nunique().sort_values(ascending=False).head()
# Out:
# city
# Valle de México    32
# Monterrey          11
# Guadalajara        10
# Toluca              6
# León                3
# Name: estacionesid, dtype: int64

# %%
estaciones_ciudad[estaciones_ciudad.city=='Valle de México'].merge(estaciones)
# Out:
#                city             state  estacionesid                       _id  \
# 0   Valle de México  Ciudad de México           242  5b8850e3e2705c1932e8306b
# 1   Valle de México  Ciudad de México           243  5b8850e3e2705c1932e8306c
# 2   Valle de México  Ciudad de México           244  5b8850e3e2705c1932e8306d
# 3   Valle de México  Ciudad de México           245  5b8850e3e2705c1932e8306e
# 4   Valle de México  Ciudad de México           248  5b8850e3e2705c1932e83071
# 5   Valle de México  Ciudad de México           250  5b8850e3e2705c1932e83073
# 6   Valle de México  Ciudad de México           251  5b8850e3e2705c1932e83074
# 7   Valle de México  Ciudad de México           253  5b8850e3e2705c1932e83076
# 8   Valle de México  Ciudad de México           256  5b8850e3e2705c1932e83078
# 9   Valle de México  Ciudad de México           257  5b8850e3e2705c1932e83079
# 10  Valle de México  Ciudad de México           259  5b8850e3e2705c1932e8307b
# 11  Valle de México  Ciudad de México           260  5b8850e3e2705c1932e8307c
# 12  Valle de México  Ciudad de México           262  5b8850e3e2705c1932e8307e
# 13  Valle de México  Ciudad de México           263  5b8850e3e2705c1932e8307f
# 14  Valle de México  Ciudad de México           266  5b8850e3e2705c1932e83081
# 15  Valle de México  Ciudad de México           267  5b8850e3e2705c1932e83082
# 16  Valle de México  Ciudad de México           268  5b8850e3e2705c1932e83083
# 17  Valle de México  Ciudad de México           269  5b8850e3e2705c1932e83084
# 18  Valle de México  Ciudad de México           270  5b8850e3e2705c1932e83085
# 19  Valle de México  Ciudad de México           271  5b8850e3e2705c1932e83086
# 20  Valle de México  Ciudad de México           300  5b8850e3e2705c1932e8308d
# 21  Valle de México  Ciudad de México           301  5b8850e3e2705c1932e8308e
# 22  Valle de México  Ciudad de México           240  5b8850e3e2705c1932e83069
# 23  Valle de México  Ciudad de México           241  5b8850e3e2705c1932e8306a
# 24  Valle de México  Ciudad de México           246  5b8850e3e2705c1932e8306f
# 25  Valle de México  Ciudad de México           249  5b8850e3e2705c1932e83072
# 26  Valle de México  Ciudad de México           252  5b8850e3e2705c1932e83075
# 27  Valle de México  Ciudad de México           254  5b8850e3e2705c1932e83077
# 28  Valle de México  Ciudad de México           258  5b8850e3e2705c1932e8307a
# 29  Valle de México  Ciudad de México           265  5b8850e3e2705c1932e83080
# 30  Valle de México  Ciudad de México           299  5b8850e3e2705c1932e8308c
# 31  Valle de México  Ciudad de México           302  5b8850e3e2705c1932e8308f
#
#           lat       long                                           nombre  \
# 0   19.272222 -99.207778                                     Ajusco Medio
# 1   19.577222 -99.254167                                         Atizapán
# 2   19.468611 -99.170000                                        Camarones
# 3   19.326389 -99.176111               Centro de Ciencias de la Atmósfera
# 4   19.365556 -99.291944                                       Cuajimalpa
# 5   19.482500 -99.243611                                      FES Acatlán
# 6   19.411667 -99.152222                       Hospital General de México
# 7   19.535000 -99.117778                                         La Presa
# 8   19.424722 -99.119722                                           Merced
# 9   19.460417 -98.902861                                       Montecillo
# 10  19.325278 -99.204167                                         Pedregal
# 11  19.533056 -99.030556                                      San Agustín
# 12  19.357500 -99.263056                                         Santa Fe
# 13  19.404000 -99.202722                                   Miguel Hidalgo
# 14  19.529167 -99.204722                                     Tlalnepantla
# 15  19.602778 -99.177222                                        Tultitlán
# 16  19.360833 -99.073889                                   UAM Iztapalapa
# 17  19.304444 -99.103889                                   UAM Xochimilco
# 18  19.657500 -99.096667                              Villa de las Flores
# 19  19.526111 -99.082500                                         Xalostoc
# 20  19.371667 -99.159167                                    Benito Juárez
# 21  19.292222 -99.380556  Instituto Nacional de Investigaciones Nucleares
# 22  19.635556 -98.912222                                          Acolman
# 23  19.154286 -99.162778                                           Ajusco
# 24  19.267222 -98.886111                                           Chalco
# 25  19.722222 -99.198611                                       Cuautitlán
# 26  19.384444 -99.117778                                        Iztacalco
# 27  19.578889 -99.039722                                     Los Laureles
# 28  19.393889 -99.028333                                   Nezahualcóyotl
# 29  19.246667 -99.010833                                          Tlahuac
# 30  19.199167 -99.010833                                       Milpa Alta
# 31  19.482778 -99.094722                                Gustavo A. Madero
#
#    codigo  redesid              date-insert
# 0     AJM      119  2018-08-30 20:17:39.225
# 1     ATI      119  2018-08-30 20:17:39.225
# 2     CAM      119  2018-08-30 20:17:39.225
# 3     CCA      119  2018-08-30 20:17:39.225
# 4     CUA      119  2018-08-30 20:17:39.225
# 5     FAC      119  2018-08-30 20:17:39.225
# 6     HGM      119  2018-08-30 20:17:39.225
# 7     LPR      119  2018-08-30 20:17:39.225
# 8     MER      119  2018-08-30 20:17:39.225
# 9     MON      119  2018-08-30 20:17:39.225
# 10    PED      119  2018-08-30 20:17:39.225
# 11    SAG      119  2018-08-30 20:17:39.225
# 12    SFE      119  2018-08-30 20:17:39.225
# 13    MGH      119  2018-08-30 20:17:39.225
# 14    TLA      119  2018-08-30 20:17:39.225
# 15    TLI      119  2018-08-30 20:17:39.225
# 16    UIZ      119  2018-08-30 20:17:39.225
# 17    UAX      119  2018-08-30 20:17:39.225
# 18    VIF      119  2018-08-30 20:17:39.226
# 19    XAL      119  2018-08-30 20:17:39.226
# 20    BJU      119  2018-08-30 20:17:39.226
# 21    INN      119  2018-08-30 20:17:39.226
# 22    ACO      119  2018-08-30 20:17:39.225
# 23    AJU      119  2018-08-30 20:17:39.225
# 24    CHO      119  2018-08-30 20:17:39.225
# 25    CUT      119  2018-08-30 20:17:39.225
# 26    IZT      119  2018-08-30 20:17:39.225
# 27    LLA      119  2018-08-30 20:17:39.225
# 28    NEZ      119  2018-08-30 20:17:39.225
# 29    TAH      119  2018-08-30 20:17:39.225
# 30    MPA      119  2018-08-30 20:17:39.226
# 31    GAM      119  2018-08-30 20:17:39.226

# %% [markdown]
# # Predicción de Ozono para el Valle de México

# %%
ciudad = mediciones[(mediciones.city.isin(['Valle de México']))]
ciudad['fecha_hora']  = pd.to_datetime(ciudad.fecha + ' ' +
                                            ciudad.hora.astype(str) +':00:00')

ciudad['fecha'] = pd.to_datetime(ciudad.fecha)

ciudad['dia_semana'] = ciudad.fecha.dt.weekday_name

O3_valleMex = ciudad[(ciudad.parametro.isin(['O3']))]

O3_valleMex = O3_valleMex.sort_values('fecha_hora')
print(O3_valleMex.shape)
O3_valleMex.head()
# Out:
# (152281, 10)
#                     city  estacionesid      fecha  hora parametro  \
# 1891057  Valle de México           240 2018-01-01     0        O3
# 2718294  Valle de México           301 2018-01-01     0        O3
# 2052820  Valle de México           249 2018-01-01     0        O3
# 2078440  Valle de México           250 2018-01-01     0        O3
# 2104364  Valle de México           251 2018-01-01     0        O3
#
#                     state  validoorig  valororig fecha_hora dia_semana
# 1891057  Ciudad de México           1      0.011 2018-01-01     Monday
# 2718294  Ciudad de México           1      0.038 2018-01-01     Monday
# 2052820  Ciudad de México           1      0.018 2018-01-01     Monday
# 2078440  Ciudad de México           1      0.026 2018-01-01     Monday
# 2104364  Ciudad de México           1      0.015 2018-01-01     Monday

# %% [markdown]
# ## Para el Valle de México por hora

# %%
ts_estacion = O3_valleMex.groupby('fecha_hora').valororig.mean().reset_index()
ts_estacion['fecha_hora'] = pd.to_datetime(ts_estacion.fecha_hora)

ntest = 12

ts_test = ts_estacion[-ntest::][['fecha_hora', 'valororig']]
ts_test.columns = ['ds', 'y']

ts_estacion = ts_estacion[['fecha_hora', 'valororig']][0:-ntest]
ts_estacion.columns = ['ds', 'y']

# Vamos a llenar los valores donde no tenemos mediciones con la media por dia de la semana y hora
ts_estacion = ts_estacion.set_index('ds').resample('H').mean() # mediciones consecutivas por hora
ts_estacion['weekday'] = ts_estacion.index.weekday_name
ts_estacion['hora'] = ts_estacion.index.hour
# Con estos 
fillnas = ts_estacion.groupby(['weekday', 'hora']).transform('mean').y
ts_estacion['y'] = np.where(ts_estacion.y.isnull(), fillnas, ts_estacion.y)

ts_estacion = ts_estacion[['y']].reset_index()

print(ts_estacion.shape)
ts_estacion.head()
# Out:
# (5908, 2)
#                    ds         y
# 0 2018-01-01 00:00:00  0.016519
# 1 2018-01-01 01:00:00  0.019481
# 2 2018-01-01 02:00:00  0.020308
# 3 2018-01-01 03:00:00  0.018704
# 4 2018-01-01 04:00:00  0.017462

# %%
m = Prophet(yearly_seasonality=False).fit(ts_estacion)
future = m.make_future_dataframe(periods=30, freq='H')
fcst = m.predict(future)
fig = m.plot(fcst)
# Out:
# /home/fickincool/anaconda3/envs/opi_py36/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
errors = fcst.merge(ts_test, on='ds')
errors['RAE'] = abs(errors.y-errors.yhat)/errors.y
print(errors.shape)
errors
# Out:
# (12, 21)
#                     ds     trend  trend_lower  trend_upper  yhat_lower  \
# 0  2018-09-04 04:00:00  0.029471     0.029471     0.029471   -0.001409
# 1  2018-09-04 05:00:00  0.029470     0.029470     0.029470   -0.002319
# 2  2018-09-04 06:00:00  0.029469     0.029469     0.029469   -0.007617
# 3  2018-09-04 07:00:00  0.029468     0.029468     0.029468   -0.011129
# 4  2018-09-04 08:00:00  0.029468     0.029468     0.029468   -0.011974
# 5  2018-09-04 09:00:00  0.029467     0.029467     0.029467   -0.010294
# 6  2018-09-04 10:00:00  0.029466     0.029466     0.029466   -0.000645
# 7  2018-09-04 11:00:00  0.029465     0.029465     0.029465    0.011128
# 8  2018-09-04 12:00:00  0.029464     0.029464     0.029464    0.024191
# 9  2018-09-04 13:00:00  0.029463     0.029463     0.029463    0.037625
# 10 2018-09-04 14:00:00  0.029463     0.029463     0.029463    0.048279
# 11 2018-09-04 15:00:00  0.029462     0.029462     0.029462    0.053656
#
#     yhat_upper     daily  daily_lower  daily_upper  seasonal    ...     \
# 0     0.026339 -0.016483    -0.016483    -0.016483 -0.017580    ...
# 1     0.024867 -0.018248    -0.018248    -0.018248 -0.019368    ...
# 2     0.020791 -0.021753    -0.021753    -0.021753 -0.022888    ...
# 3     0.015984 -0.025493    -0.025493    -0.025493 -0.026639    ...
# 4     0.014425 -0.026940    -0.026940    -0.026940 -0.028090    ...
# 5     0.017778 -0.023937    -0.023937    -0.023937 -0.025086    ...
# 6     0.025939 -0.015857    -0.015857    -0.015857 -0.017000    ...
# 7     0.037209 -0.003805    -0.003805    -0.003805 -0.004939    ...
# 8     0.051722  0.010031     0.010031     0.010031  0.008911    ...
# 9     0.064040  0.023232     0.023232     0.023232  0.022129    ...
# 10    0.075619  0.033653     0.033653     0.033653  0.032568    ...
# 11    0.081165  0.039608     0.039608     0.039608  0.038545    ...
#
#     seasonal_upper  seasonalities  seasonalities_lower  seasonalities_upper  \
# 0        -0.017580      -0.017580            -0.017580            -0.017580
# 1        -0.019368      -0.019368            -0.019368            -0.019368
# 2        -0.022888      -0.022888            -0.022888            -0.022888
# 3        -0.026639      -0.026639            -0.026639            -0.026639
# 4        -0.028090      -0.028090            -0.028090            -0.028090
# 5        -0.025086      -0.025086            -0.025086            -0.025086
# 6        -0.017000      -0.017000            -0.017000            -0.017000
# 7        -0.004939      -0.004939            -0.004939            -0.004939
# 8         0.008911       0.008911             0.008911             0.008911
# 9         0.022129       0.022129             0.022129             0.022129
# 10        0.032568       0.032568             0.032568             0.032568
# 11        0.038545       0.038545             0.038545             0.038545
#
#       weekly  weekly_lower  weekly_upper      yhat         y       RAE
# 0  -0.001097     -0.001097     -0.001097  0.011891  0.013310  0.106649
# 1  -0.001119     -0.001119     -0.001119  0.010102  0.011310  0.106801
# 2  -0.001136     -0.001136     -0.001136  0.006581  0.007250  0.092289
# 3  -0.001146     -0.001146     -0.001146  0.002830  0.003828  0.260681
# 4  -0.001150     -0.001150     -0.001150  0.001378  0.003067  0.550803
# 5  -0.001149     -0.001149     -0.001149  0.004381  0.004645  0.056958
# 6  -0.001144     -0.001144     -0.001144  0.012466  0.011387  0.094731
# 7  -0.001134     -0.001134     -0.001134  0.024526  0.019759  0.241299
# 8  -0.001120     -0.001120     -0.001120  0.038375  0.034690  0.106240
# 9  -0.001104     -0.001104     -0.001104  0.051592  0.053407  0.033990
# 10 -0.001085     -0.001085     -0.001085  0.062031  0.071571  0.133300
# 11 -0.001063     -0.001063     -0.001063  0.068006  0.083923  0.189658
#
# [12 rows x 21 columns]

# %%
errors.plot.scatter('y', 'yhat')
plt.plot(errors.y, errors.y, color='red')

# %%
display(errors.RAE.describe())
errors.plot(x='ds', y=['y', 'yhat'], style='-o')
# Out:
# count    12.000000
# mean      0.164450
# std       0.139719
# min       0.033990
# 25%       0.094121
# 50%       0.106725
# 75%       0.202569
# max       0.550803
# Name: RAE, dtype: float64
# /home/fickincool/anaconda3/envs/opi_py36/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
fig = m.plot_components(fcst)

# %% [markdown]
# # Predicción de Ozono para Guadalajara

# %%
ciudad = mediciones[(mediciones.city.isin(['Guadalajara']))]
ciudad['fecha_hora']  = pd.to_datetime(ciudad.fecha + ' ' +
                                            ciudad.hora.astype(str) +':00:00')

ciudad['fecha'] = pd.to_datetime(ciudad.fecha)

ciudad['dia_semana'] = ciudad.fecha.dt.weekday_name

O3_gdl = ciudad[(ciudad.parametro.isin(['O3']))]

O3_gdl = O3_gdl.sort_values('fecha_hora')
print(O3_gdl.shape)
O3_gdl.head()
# Out:
# (50232, 10)
#                city  estacionesid      fecha  hora parametro    state  \
# 840905  Guadalajara           104 2018-01-01     0        O3  Jalisco
# 864430  Guadalajara           105 2018-01-01     0        O3  Jalisco
# 918653  Guadalajara           107 2018-01-01     0        O3  Jalisco
# 774286  Guadalajara           102 2018-01-01     0        O3  Jalisco
# 984343  Guadalajara           109 2018-01-01     0        O3  Jalisco
#
#         validoorig  valororig fecha_hora dia_semana
# 840905           1   0.017321 2018-01-01     Monday
# 864430           1   0.024202 2018-01-01     Monday
# 918653           1   0.005754 2018-01-01     Monday
# 774286           1   0.009149 2018-01-01     Monday
# 984343           1   0.008100 2018-01-01     Monday

# %% [markdown]
# ## Para GDL por hora

# %%
ts_estacion = O3_gdl.groupby('fecha_hora').valororig.mean().reset_index()
ts_estacion['fecha_hora'] = pd.to_datetime(ts_estacion.fecha_hora)

ntest = 12

ts_test = ts_estacion[-ntest::][['fecha_hora', 'valororig']]
ts_test.columns = ['ds', 'y']

ts_estacion = ts_estacion[['fecha_hora', 'valororig']][0:-ntest]
ts_estacion.columns = ['ds', 'y']

# Vamos a llenar los valores donde no tenemos mediciones con la media por dia de la semana y hora
ts_estacion = ts_estacion.set_index('ds').resample('H').mean() # mediciones consecutivas por hora
ts_estacion['weekday'] = ts_estacion.index.weekday_name
ts_estacion['hora'] = ts_estacion.index.hour
# Con estos 
fillnas = ts_estacion.groupby(['weekday', 'hora']).transform('mean').y
ts_estacion['y'] = np.where(ts_estacion.y.isnull(), fillnas, ts_estacion.y)

ts_estacion = ts_estacion[['y']].reset_index()

print(ts_estacion.shape)
ts_estacion.head()
# Out:
# (5907, 2)
#                    ds         y
# 0 2018-01-01 00:00:00  0.017213
# 1 2018-01-01 01:00:00  0.013317
# 2 2018-01-01 02:00:00  0.009076
# 3 2018-01-01 03:00:00  0.004476
# 4 2018-01-01 04:00:00  0.005072

# %%
m = Prophet(yearly_seasonality=False).fit(ts_estacion)
future = m.make_future_dataframe(periods=30, freq='H')
fcst = m.predict(future)
fig = m.plot(fcst)
# Out:
# /home/fickincool/anaconda3/envs/opi_py36/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
errors = fcst.merge(ts_test, on='ds')
errors['RAE'] = abs(errors.y-errors.yhat)/errors.y
print(errors.shape)
errors
# Out:
# (12, 21)
#                     ds     trend  trend_lower  trend_upper  yhat_lower  \
# 0  2018-09-04 03:00:00  0.031341     0.031341     0.031341    0.007969
# 1  2018-09-04 04:00:00  0.031336     0.031336     0.031336    0.006807
# 2  2018-09-04 05:00:00  0.031330     0.031330     0.031330    0.004390
# 3  2018-09-04 06:00:00  0.031325     0.031325     0.031325    0.000369
# 4  2018-09-04 07:00:00  0.031319     0.031319     0.031319   -0.004964
# 5  2018-09-04 08:00:00  0.031314     0.031314     0.031314   -0.007953
# 6  2018-09-04 09:00:00  0.031308     0.031308     0.031308   -0.004735
# 7  2018-09-04 10:00:00  0.031303     0.031303     0.031303    0.002721
# 8  2018-09-04 11:00:00  0.031297     0.031297     0.031297    0.016228
# 9  2018-09-04 12:00:00  0.031291     0.031291     0.031291    0.027677
# 10 2018-09-04 13:00:00  0.031286     0.031286     0.031286    0.036739
# 11 2018-09-04 14:00:00  0.031280     0.031280     0.031280    0.041909
#
#     yhat_upper     daily  daily_lower  daily_upper  seasonal    ...     \
# 0     0.033709 -0.009458    -0.009458    -0.009458 -0.010367    ...
# 1     0.033706 -0.010624    -0.010624    -0.010624 -0.011520    ...
# 2     0.029715 -0.013065    -0.013065    -0.013065 -0.013946    ...
# 3     0.027083 -0.017221    -0.017221    -0.017221 -0.018089    ...
# 4     0.020537 -0.021913    -0.021913    -0.021913 -0.022767    ...
# 5     0.019682 -0.024342    -0.024342    -0.024342 -0.025183    ...
# 6     0.022135 -0.021738    -0.021738    -0.021738 -0.022566    ...
# 7     0.029949 -0.013426    -0.013426    -0.013426 -0.014241    ...
# 8     0.042285 -0.001526    -0.001526    -0.001526 -0.002329    ...
# 9     0.053319  0.010373     0.010373     0.010373  0.009583    ...
# 10    0.063010  0.019469     0.019469     0.019469  0.018691    ...
# 11    0.069133  0.025030     0.025030     0.025030  0.024265    ...
#
#     seasonal_upper  seasonalities  seasonalities_lower  seasonalities_upper  \
# 0        -0.010367      -0.010367            -0.010367            -0.010367
# 1        -0.011520      -0.011520            -0.011520            -0.011520
# 2        -0.013946      -0.013946            -0.013946            -0.013946
# 3        -0.018089      -0.018089            -0.018089            -0.018089
# 4        -0.022767      -0.022767            -0.022767            -0.022767
# 5        -0.025183      -0.025183            -0.025183            -0.025183
# 6        -0.022566      -0.022566            -0.022566            -0.022566
# 7        -0.014241      -0.014241            -0.014241            -0.014241
# 8        -0.002329      -0.002329            -0.002329            -0.002329
# 9         0.009583       0.009583             0.009583             0.009583
# 10        0.018691       0.018691             0.018691             0.018691
# 11        0.024265       0.024265             0.024265             0.024265
#
#       weekly  weekly_lower  weekly_upper      yhat         y       RAE
# 0  -0.000909     -0.000909     -0.000909  0.020974  0.028992  0.276540
# 1  -0.000896     -0.000896     -0.000896  0.019816  0.027573  0.281328
# 2  -0.000882     -0.000882     -0.000882  0.017384  0.022275  0.219594
# 3  -0.000868     -0.000868     -0.000868  0.013236  0.016581  0.201719
# 4  -0.000854     -0.000854     -0.000854  0.008552  0.009904  0.136452
# 5  -0.000841     -0.000841     -0.000841  0.006131  0.008595  0.286705
# 6  -0.000828     -0.000828     -0.000828  0.008742  0.011297  0.226154
# 7  -0.000815     -0.000815     -0.000815  0.017062  0.014296  0.193464
# 8  -0.000802     -0.000802     -0.000802  0.028968  0.020503  0.412898
# 9  -0.000790     -0.000790     -0.000790  0.040874  0.031405  0.301535
# 10 -0.000778     -0.000778     -0.000778  0.049977  0.044952  0.111787
# 11 -0.000765     -0.000765     -0.000765  0.055545  0.062250  0.107703
#
# [12 rows x 21 columns]

# %%
errors.plot.scatter('y', 'yhat')
plt.plot(errors.y, errors.y, color='red')

# %%
display(errors.RAE.describe())
errors.plot(x='ds', y=['y', 'yhat'], style='-o')
# Out:
# count    12.000000
# mean      0.229657
# std       0.088689
# min       0.107703
# 25%       0.179211
# 50%       0.222874
# 75%       0.282673
# max       0.412898
# Name: RAE, dtype: float64
# /home/fickincool/anaconda3/envs/opi_py36/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
fig = m.plot_components(fcst)

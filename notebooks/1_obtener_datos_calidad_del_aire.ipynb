# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Parámetros" data-toc-modified-id="Parámetros-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Parámetros</a></span></li><li><span><a href="#Estaciones" data-toc-modified-id="Estaciones-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Estaciones</a></span></li><li><span><a href="#Obtener-todos-los-registros-de-mediciones" data-toc-modified-id="Obtener-todos-los-registros-de-mediciones-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Obtener todos los registros de mediciones</a></span><ul class="toc-item"><li><span><a href="#Obtener-jsons" data-toc-modified-id="Obtener-jsons-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Obtener jsons</a></span></li><li><span><a href="#Formatear-json-a-csv" data-toc-modified-id="Formatear-json-a-csv-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Formatear json a csv</a></span></li></ul></li></ul></div>

# %%
# Vamos a utilizar estas librerías
import pandas as pd
import requests
import json
import numpy as np
from datosgobmx import client # https://github.com/mxabierto/api_python_client
import mplleaflet

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Parámetros

# %%
# Obtener los parámetros válidos para la API usando el endpoint de Sinaica
parametros_request = client.makeCall('sinaica-parametros')

valid_params = []

for v in parametros_request['results']:
    aux = pd.DataFrame.from_dict(v, orient='index').T
    valid_params.append(aux)
    
valid_params = pd.concat(valid_params, ignore_index=True)
valid_params['date-insert'] = pd.to_datetime(valid_params['date-insert'])
valid_params
# Out:
# CALL: https://api.datos.gob.mx/v2/sinaica-parametros
#                         _id parametro             date-insert
# 0  5ba1176fe2705c1932aa83e7      PM10 2018-09-18 15:19:11.304
# 1  5ba1176fe2705c1932aa83e8       SO2 2018-09-18 15:19:11.304
# 2  5ba1176fe2705c1932aa83e9        CO 2018-09-18 15:19:11.304
# 3  5ba1176fe2705c1932aa83ea        O3 2018-09-18 15:19:11.304
# 4  5ba1176fe2705c1932aa83eb       NO2 2018-09-18 15:19:11.304
# 5  5ba1176fe2705c1932aa83ec       TMP 2018-09-18 15:19:11.304
# 6  5ba1176fe2705c1932aa83ed     PM2.5 2018-09-18 15:19:11.304

# %% [markdown]
# # Estaciones

# %%
estaciones_request = client.makeCall('sinaica-estaciones', {'pageSize':200})

estaciones = []

for v in estaciones_request['results']:
    aux = pd.DataFrame.from_dict(v, orient='index').T
    estaciones.append(aux)
    
estaciones = pd.concat(estaciones, ignore_index=True)
estaciones['date-insert'] = pd.to_datetime(estaciones['date-insert'])
estaciones = estaciones.apply(lambda x: pd.to_numeric(x, errors='ignore') if x.name!='date-insert' else x)

print(estaciones.shape)
estaciones.head()
# Out:
# CALL: https://api.datos.gob.mx/v2/sinaica-estaciones?pageSize=200
# (184, 8)
#                         _id        lat        long  id  \
# 0  5ba1176fe2705c1932aa83f0  21.873311 -102.320803  31
# 1  5ba1176fe2705c1932aa83f1  21.846392 -102.288431  32
# 2  5ba1176fe2705c1932aa83f2  21.883781 -102.295825  33
# 3  5ba1176fe2705c1932aa83f3  31.859917 -116.593722  36
# 4  5ba1176fe2705c1932aa83f4  32.631317 -115.444631  38
#
#                          nombre   codigo  redesid             date-insert
# 0                        CBTIS       CBT       30 2018-09-18 15:19:11.373
# 1  Secretaría de Medio Ambiente      SMA       30 2018-09-18 15:19:11.373
# 2                        Centro      CEN       30 2018-09-18 15:19:11.373
# 3                    Secundaria  SPABC20       31 2018-09-18 15:19:11.373
# 4                          UABC  SPABC12       32 2018-09-18 15:19:11.373

# %%
estaciones.describe()
# Out:
#               lat        long          id     redesid
# count  184.000000  184.000000  184.000000  184.000000
# mean    21.925474  -99.709699  191.184783   77.635870
# std      5.400582   15.759411  112.805159   32.670787
# min      0.000000 -117.056111   31.000000   30.000000
# 25%     19.391528 -103.316076   95.250000   48.000000
# 50%     20.570912 -100.355139  165.500000   72.000000
# 75%     25.526816  -99.119272  267.250000  119.000000
# max     34.570000    0.000000  427.000000  149.000000

# %%
estaciones.id.nunique(), estaciones._id.nunique(), estaciones.lat.nunique(), estaciones.long.nunique()
# Out:
# (184, 184, 178, 177)

# %%
# Estaciones son los datos obtenidos de la API, en formato Pandas DataFrame
# Hay estaciones con valores erróneos
estaciones.plot.scatter('long', 'lat', figsize=(8, 8))
mplleaflet.display()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="480"></iframe>

# %%
# Guardamos lo datos para utilizarlos más adelante
# estaciones.to_csv('/data_estaciones_sinaica.csv', index=False)

# %% [markdown]
# # Obtener todos los registros de mediciones

# %%
# Ejemplo
client.makeCall('sinaica', {'pageSize':5000, 'page':1})
# Out:
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=1
# {'pagination': {'page': 1, 'pageSize': 5000, 'total': 3244509},
#  'results': [{'_id': '5b8ef752e2705c1932ce5ee4',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T01:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.989Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 1,
#    'id': '101CO18010101',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.3865},
#   {'_id': '5b8ef752e2705c1932ce5ee5',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T02:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.995Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 2,
#    'id': '101CO18010102',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.8923},
#   {'_id': '5b8ef752e2705c1932ce5ee6',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T03:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.995Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 3,
#    'id': '101CO18010103',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.8105},
#   {'_id': '5b8ef752e2705c1932ce5ee7',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T04:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.995Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 4,
#    'id': '101CO18010104',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.4355},
#   {'_id': '5b8ef752e2705c1932ce5ee8',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T05:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.995Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 5,
#    'id': '101CO18010105',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.9326},
#   {'_id': '5b8ef752e2705c1932ce5ee9',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T06:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.995Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 6,
#    'id': '101CO18010106',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.8677},
#   {'_id': '5b8ef752e2705c1932ce5eea',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T07:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.995Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 7,
#    'id': '101CO18010107',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.9507},
#   {'_id': '5b8ef752e2705c1932ce5eeb',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T08:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.995Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 8,
#    'id': '101CO18010108',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.2974},
#   {'_id': '5b8ef752e2705c1932ce5eec',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T09:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.996Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 9,
#    'id': '101CO18010109',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.6891},
#   {'_id': '5b8ef752e2705c1932ce5eed',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T10:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.996Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 10,
#    'id': '101CO18010110',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.0474},
#   {'_id': '5b8ef752e2705c1932ce5eee',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T11:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.996Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 11,
#    'id': '101CO18010111',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.71526},
#   {'_id': '5b8ef752e2705c1932ce5eef',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T12:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.996Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 12,
#    'id': '101CO18010112',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.55633},
#   {'_id': '5b8ef752e2705c1932ce5ef0',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T13:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.996Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 13,
#    'id': '101CO18010113',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.54382},
#   {'_id': '5b8ef752e2705c1932ce5ef1',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T14:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.996Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 14,
#    'id': '101CO18010114',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.55089},
#   {'_id': '5b8ef752e2705c1932ce5ef2',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T15:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.996Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 15,
#    'id': '101CO18010115',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.58439},
#   {'_id': '5b8ef752e2705c1932ce5ef3',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T16:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.997Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 16,
#    'id': '101CO18010116',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.61626},
#   {'_id': '5b8ef752e2705c1932ce5ef4',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T17:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.997Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 17,
#    'id': '101CO18010117',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.59049},
#   {'_id': '5b8ef752e2705c1932ce5ef5',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T18:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.997Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 18,
#    'id': '101CO18010118',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.69288},
#   {'_id': '5b8ef752e2705c1932ce5ef6',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T19:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.998Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 19,
#    'id': '101CO18010119',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.5533},
#   {'_id': '5b8ef752e2705c1932ce5ef7',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T20:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.998Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 20,
#    'id': '101CO18010120',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.0583},
#   {'_id': '5b8ef752e2705c1932ce5ef8',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T21:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.998Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 21,
#    'id': '101CO18010121',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.9055},
#   {'_id': '5b8ef752e2705c1932ce5ef9',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T22:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.998Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 22,
#    'id': '101CO18010122',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.6002},
#   {'_id': '5b8ef752e2705c1932ce5efa',
#    'city': 'Guadalajara',
#    'date': '2018-01-01T23:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.999Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-01',
#    'hora': 23,
#    'id': '101CO18010123',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.7369},
#   {'_id': '5b8ef752e2705c1932ce5efb',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T00:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.999Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 0,
#    'id': '101CO18010200',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.3251},
#   {'_id': '5b8ef752e2705c1932ce5efc',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T01:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.999Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 1,
#    'id': '101CO18010201',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.3489},
#   {'_id': '5b8ef752e2705c1932ce5efd',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T02:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.999Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 2,
#    'id': '101CO18010202',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.5158},
#   {'_id': '5b8ef752e2705c1932ce5efe',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T03:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.999Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 3,
#    'id': '101CO18010203',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.4304},
#   {'_id': '5b8ef752e2705c1932ce5eff',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T04:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.999Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 4,
#    'id': '101CO18010204',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.4315},
#   {'_id': '5b8ef752e2705c1932ce5f00',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T05:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.999Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 5,
#    'id': '101CO18010205',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.4919},
#   {'_id': '5b8ef752e2705c1932ce5f01',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T06:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:21.999Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 6,
#    'id': '101CO18010206',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.7193},
#   {'_id': '5b8ef752e2705c1932ce5f02',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T07:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.000Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 7,
#    'id': '101CO18010207',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.1188},
#   {'_id': '5b8ef752e2705c1932ce5f03',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T08:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.000Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 8,
#    'id': '101CO18010208',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.5056},
#   {'_id': '5b8ef752e2705c1932ce5f04',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T09:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.000Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 9,
#    'id': '101CO18010209',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.3159},
#   {'_id': '5b8ef752e2705c1932ce5f05',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T10:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.000Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 10,
#    'id': '101CO18010210',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.93638},
#   {'_id': '5b8ef752e2705c1932ce5f06',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T11:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.000Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 11,
#    'id': '101CO18010211',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.83932},
#   {'_id': '5b8ef752e2705c1932ce5f07',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T12:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.000Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 12,
#    'id': '101CO18010212',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.72842},
#   {'_id': '5b8ef752e2705c1932ce5f08',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T13:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.000Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 13,
#    'id': '101CO18010213',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.77392},
#   {'_id': '5b8ef752e2705c1932ce5f09',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T14:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.000Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 14,
#    'id': '101CO18010214',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.77824},
#   {'_id': '5b8ef752e2705c1932ce5f0a',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T15:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.000Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 15,
#    'id': '101CO18010215',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.73088},
#   {'_id': '5b8ef752e2705c1932ce5f0b',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T16:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.000Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 16,
#    'id': '101CO18010216',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.75198},
#   {'_id': '5b8ef752e2705c1932ce5f0c',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T17:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.001Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 17,
#    'id': '101CO18010217',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.76346},
#   {'_id': '5b8ef752e2705c1932ce5f0d',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T18:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.001Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 18,
#    'id': '101CO18010218',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.86681},
#   {'_id': '5b8ef752e2705c1932ce5f0e',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T19:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.001Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 19,
#    'id': '101CO18010219',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.9509},
#   {'_id': '5b8ef752e2705c1932ce5f0f',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T20:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.001Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 20,
#    'id': '101CO18010220',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.6858},
#   {'_id': '5b8ef752e2705c1932ce5f10',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T21:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.001Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 21,
#    'id': '101CO18010221',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.2525},
#   {'_id': '5b8ef752e2705c1932ce5f11',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T22:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.001Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 22,
#    'id': '101CO18010222',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.0773},
#   {'_id': '5b8ef752e2705c1932ce5f12',
#    'city': 'Guadalajara',
#    'date': '2018-01-02T23:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.001Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-02',
#    'hora': 23,
#    'id': '101CO18010223',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.7502},
#   {'_id': '5b8ef752e2705c1932ce5f13',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T00:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.001Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 0,
#    'id': '101CO18010300',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.1973},
#   {'_id': '5b8ef752e2705c1932ce5f14',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T01:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.001Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 1,
#    'id': '101CO18010301',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.89746},
#   {'_id': '5b8ef752e2705c1932ce5f15',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T02:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.002Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 2,
#    'id': '101CO18010302',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.87701},
#   {'_id': '5b8ef752e2705c1932ce5f16',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T03:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.002Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 3,
#    'id': '101CO18010303',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.76006},
#   {'_id': '5b8ef752e2705c1932ce5f17',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T04:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.002Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 4,
#    'id': '101CO18010304',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.70318},
#   {'_id': '5b8ef752e2705c1932ce5f18',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T05:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.002Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 5,
#    'id': '101CO18010305',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.66415},
#   {'_id': '5b8ef752e2705c1932ce5f19',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T06:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.002Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 6,
#    'id': '101CO18010306',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.2258},
#   {'_id': '5b8ef752e2705c1932ce5f1a',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T07:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.002Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 7,
#    'id': '101CO18010307',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.6283},
#   {'_id': '5b8ef752e2705c1932ce5f1b',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T08:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.002Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 8,
#    'id': '101CO18010308',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.0295},
#   {'_id': '5b8ef752e2705c1932ce5f1c',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T09:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.002Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 9,
#    'id': '101CO18010309',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.4369},
#   {'_id': '5b8ef752e2705c1932ce5f1d',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T10:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.002Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 10,
#    'id': '101CO18010310',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.148},
#   {'_id': '5b8ef752e2705c1932ce5f1e',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T11:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.002Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 11,
#    'id': '101CO18010311',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.0386},
#   {'_id': '5b8ef752e2705c1932ce5f1f',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T12:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.002Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 12,
#    'id': '101CO18010312',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.78343},
#   {'_id': '5b8ef752e2705c1932ce5f20',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T13:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.002Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 13,
#    'id': '101CO18010313',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.62067},
#   {'_id': '5b8ef752e2705c1932ce5f21',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T14:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.003Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 14,
#    'id': '101CO18010314',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.58582},
#   {'_id': '5b8ef752e2705c1932ce5f22',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T15:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.003Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 15,
#    'id': '101CO18010315',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.65802},
#   {'_id': '5b8ef752e2705c1932ce5f23',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T16:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.003Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 16,
#    'id': '101CO18010316',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.6283},
#   {'_id': '5b8ef752e2705c1932ce5f26',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T17:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.003Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 17,
#    'id': '101CO18010317',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.75388},
#   {'_id': '5b8ef752e2705c1932ce5f27',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T18:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.003Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 18,
#    'id': '101CO18010318',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.9898},
#   {'_id': '5b8ef752e2705c1932ce5f28',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T19:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.003Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 19,
#    'id': '101CO18010319',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.3806},
#   {'_id': '5b8ef752e2705c1932ce5f29',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T20:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.003Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 20,
#    'id': '101CO18010320',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.3849},
#   {'_id': '5b8ef752e2705c1932ce5f2a',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T21:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.003Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 21,
#    'id': '101CO18010321',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.2387},
#   {'_id': '5b8ef752e2705c1932ce5f2b',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T22:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.003Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 22,
#    'id': '101CO18010322',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.4634},
#   {'_id': '5b8ef752e2705c1932ce5f2c',
#    'city': 'Guadalajara',
#    'date': '2018-01-03T23:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.003Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-03',
#    'hora': 23,
#    'id': '101CO18010323',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.1469},
#   {'_id': '5b8ef752e2705c1932ce5f2d',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T00:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.003Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 0,
#    'id': '101CO18010400',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.0561},
#   {'_id': '5b8ef752e2705c1932ce5f2e',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T01:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.003Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 1,
#    'id': '101CO18010401',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.517},
#   {'_id': '5b8ef752e2705c1932ce5f2f',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T02:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.003Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 2,
#    'id': '101CO18010402',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.3181},
#   {'_id': '5b8ef752e2705c1932ce5f30',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T03:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.003Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 3,
#    'id': '101CO18010403',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.1074},
#   {'_id': '5b8ef752e2705c1932ce5f31',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T04:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 4,
#    'id': '101CO18010404',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.0513},
#   {'_id': '5b8ef752e2705c1932ce5f32',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T05:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 5,
#    'id': '101CO18010405',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.0869},
#   {'_id': '5b8ef752e2705c1932ce5f33',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T06:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 6,
#    'id': '101CO18010406',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.3794},
#   {'_id': '5b8ef752e2705c1932ce5f34',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T07:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 7,
#    'id': '101CO18010407',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.6531},
#   {'_id': '5b8ef752e2705c1932ce5f35',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T08:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 8,
#    'id': '101CO18010408',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.426},
#   {'_id': '5b8ef752e2705c1932ce5f36',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T09:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 9,
#    'id': '101CO18010409',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.8235},
#   {'_id': '5b8ef752e2705c1932ce5f37',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T10:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 10,
#    'id': '101CO18010410',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.4495},
#   {'_id': '5b8ef752e2705c1932ce5f38',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T11:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 11,
#    'id': '101CO18010411',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.98267},
#   {'_id': '5b8ef752e2705c1932ce5f39',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T12:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 12,
#    'id': '101CO18010412',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.72309},
#   {'_id': '5b8ef752e2705c1932ce5f3a',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T13:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 13,
#    'id': '101CO18010413',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.62262},
#   {'_id': '5b8ef752e2705c1932ce5f3b',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T14:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 14,
#    'id': '101CO18010414',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.72782},
#   {'_id': '5b8ef752e2705c1932ce5f3c',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T15:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 15,
#    'id': '101CO18010415',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.80159},
#   {'_id': '5b8ef752e2705c1932ce5f3d',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T16:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 16,
#    'id': '101CO18010416',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.82006},
#   {'_id': '5b8ef752e2705c1932ce5f3e',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T17:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 17,
#    'id': '101CO18010417',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.85774},
#   {'_id': '5b8ef752e2705c1932ce5f3f',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T18:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.004Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 18,
#    'id': '101CO18010418',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.75368},
#   {'_id': '5b8ef752e2705c1932ce5f40',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T19:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.005Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 19,
#    'id': '101CO18010419',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.7998},
#   {'_id': '5b8ef752e2705c1932ce5f41',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T20:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.005Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 20,
#    'id': '101CO18010420',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 4.288},
#   {'_id': '5b8ef752e2705c1932ce5f42',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T21:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.005Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 21,
#    'id': '101CO18010421',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.6139},
#   {'_id': '5b8ef752e2705c1932ce5f43',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T22:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.005Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 22,
#    'id': '101CO18010422',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.4325},
#   {'_id': '5b8ef752e2705c1932ce5f44',
#    'city': 'Guadalajara',
#    'date': '2018-01-04T23:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.005Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-04',
#    'hora': 23,
#    'id': '101CO18010423',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.0019},
#   {'_id': '5b8ef752e2705c1932ce5f45',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T00:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.005Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 0,
#    'id': '101CO18010500',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.92589},
#   {'_id': '5b8ef752e2705c1932ce5f46',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T01:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.005Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 1,
#    'id': '101CO18010501',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.6395},
#   {'_id': '5b8ef752e2705c1932ce5f47',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T02:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.005Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 2,
#    'id': '101CO18010502',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.0044},
#   {'_id': '5b8ef752e2705c1932ce5f48',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T03:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.005Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 3,
#    'id': '101CO18010503',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.76778},
#   {'_id': '5b8ef752e2705c1932ce5f49',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T04:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.005Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 4,
#    'id': '101CO18010504',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.84257},
#   {'_id': '5b8ef752e2705c1932ce5f4d',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T05:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.038Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 5,
#    'id': '101CO18010505',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.0377},
#   {'_id': '5b8ef752e2705c1932ce5f4e',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T06:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.038Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 6,
#    'id': '101CO18010506',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.3173},
#   {'_id': '5b8ef752e2705c1932ce5f4f',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T07:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.038Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 7,
#    'id': '101CO18010507',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.1796},
#   {'_id': '5b8ef752e2705c1932ce5f50',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T08:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.038Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 8,
#    'id': '101CO18010508',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.0846},
#   {'_id': '5b8ef752e2705c1932ce5f51',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T09:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.038Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 9,
#    'id': '101CO18010509',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.4162},
#   {'_id': '5b8ef752e2705c1932ce5f52',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T10:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.038Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 10,
#    'id': '101CO18010510',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.2813},
#   {'_id': '5b8ef752e2705c1932ce5f53',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T11:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.038Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 11,
#    'id': '101CO18010511',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.4812},
#   {'_id': '5b8ef752e2705c1932ce5f54',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T12:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.038Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 12,
#    'id': '101CO18010512',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.318},
#   {'_id': '5b8ef752e2705c1932ce5f55',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T13:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.038Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 13,
#    'id': '101CO18010513',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.0312},
#   {'_id': '5b8ef752e2705c1932ce5f56',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T14:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 14,
#    'id': '101CO18010514',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.71678},
#   {'_id': '5b8ef752e2705c1932ce5f57',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T15:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 15,
#    'id': '101CO18010515',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.61072},
#   {'_id': '5b8ef752e2705c1932ce5f58',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T16:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 16,
#    'id': '101CO18010516',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.53418},
#   {'_id': '5b8ef752e2705c1932ce5f59',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T17:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 17,
#    'id': '101CO18010517',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.59544},
#   {'_id': '5b8ef752e2705c1932ce5f5a',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T18:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 18,
#    'id': '101CO18010518',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.73937},
#   {'_id': '5b8ef752e2705c1932ce5f5b',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T19:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 19,
#    'id': '101CO18010519',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.0337},
#   {'_id': '5b8ef752e2705c1932ce5f5c',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T20:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 20,
#    'id': '101CO18010520',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.491},
#   {'_id': '5b8ef752e2705c1932ce5f5d',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T21:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 21,
#    'id': '101CO18010521',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.526},
#   {'_id': '5b8ef752e2705c1932ce5f5e',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T22:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 22,
#    'id': '101CO18010522',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.1987},
#   {'_id': '5b8ef752e2705c1932ce5f5f',
#    'city': 'Guadalajara',
#    'date': '2018-01-05T23:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-05',
#    'hora': 23,
#    'id': '101CO18010523',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.95182},
#   {'_id': '5b8ef752e2705c1932ce5f60',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T00:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 0,
#    'id': '101CO18010600',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.87954},
#   {'_id': '5b8ef752e2705c1932ce5f61',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T01:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 1,
#    'id': '101CO18010601',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.89358},
#   {'_id': '5b8ef752e2705c1932ce5f62',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T02:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 2,
#    'id': '101CO18010602',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.90566},
#   {'_id': '5b8ef752e2705c1932ce5f63',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T03:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 3,
#    'id': '101CO18010603',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.0591},
#   {'_id': '5b8ef752e2705c1932ce5f64',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T04:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 4,
#    'id': '101CO18010604',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.75207},
#   {'_id': '5b8ef752e2705c1932ce5f65',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T05:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 5,
#    'id': '101CO18010605',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.70852},
#   {'_id': '5b8ef752e2705c1932ce5f66',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T06:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.039Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 6,
#    'id': '101CO18010606',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.1212},
#   {'_id': '5b8ef752e2705c1932ce5f67',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T07:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 7,
#    'id': '101CO18010607',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.8526},
#   {'_id': '5b8ef752e2705c1932ce5f68',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T08:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 8,
#    'id': '101CO18010608',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.2562},
#   {'_id': '5b8ef752e2705c1932ce5f69',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T09:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 9,
#    'id': '101CO18010609',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.8849},
#   {'_id': '5b8ef752e2705c1932ce5f6a',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T10:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 10,
#    'id': '101CO18010610',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.789},
#   {'_id': '5b8ef752e2705c1932ce5f6b',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T11:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 11,
#    'id': '101CO18010611',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.1353},
#   {'_id': '5b8ef752e2705c1932ce5f6c',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T12:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 12,
#    'id': '101CO18010612',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.69188},
#   {'_id': '5b8ef752e2705c1932ce5f6d',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T13:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 13,
#    'id': '101CO18010613',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.71182},
#   {'_id': '5b8ef752e2705c1932ce5f6e',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T14:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 14,
#    'id': '101CO18010614',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.60475},
#   {'_id': '5b8ef752e2705c1932ce5f6f',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T15:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 15,
#    'id': '101CO18010615',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.69554},
#   {'_id': '5b8ef752e2705c1932ce5f70',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T16:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 16,
#    'id': '101CO18010616',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.69507},
#   {'_id': '5b8ef752e2705c1932ce5f71',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T17:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 17,
#    'id': '101CO18010617',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.65513},
#   {'_id': '5b8ef752e2705c1932ce5f72',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T18:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 18,
#    'id': '101CO18010618',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.89694},
#   {'_id': '5b8ef752e2705c1932ce5f73',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T19:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 19,
#    'id': '101CO18010619',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.5438},
#   {'_id': '5b8ef752e2705c1932ce5f74',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T20:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 20,
#    'id': '101CO18010620',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.9651},
#   {'_id': '5b8ef752e2705c1932ce5f75',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T21:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 21,
#    'id': '101CO18010621',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.6886},
#   {'_id': '5b8ef752e2705c1932ce5f76',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T22:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.040Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 22,
#    'id': '101CO18010622',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.1271},
#   {'_id': '5b8ef752e2705c1932ce5f77',
#    'city': 'Guadalajara',
#    'date': '2018-01-06T23:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.041Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-06',
#    'hora': 23,
#    'id': '101CO18010623',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.8374},
#   {'_id': '5b8ef752e2705c1932ce5f78',
#    'city': 'Guadalajara',
#    'date': '2018-01-07T00:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.041Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-07',
#    'hora': 0,
#    'id': '101CO18010700',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.9447},
#   {'_id': '5b8ef752e2705c1932ce5f79',
#    'city': 'Guadalajara',
#    'date': '2018-01-07T01:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.041Z',
#    'estacionesid': 101,
#    'fecha': '2018-01-07',
#    'hora': 1,
#    'id': '101CO18010701',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.6272},
# ...
#    'hora': 19,
#    'id': '101CO18031719',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.72875},
#   {'_id': '5b8ef752e2705c1932ce62ab',
#    'city': 'Guadalajara',
#    'date': '2018-03-17T20:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-17',
#    'hora': 20,
#    'id': '101CO18031720',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.91718},
#   {'_id': '5b8ef752e2705c1932ce62ac',
#    'city': 'Guadalajara',
#    'date': '2018-03-17T21:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-17',
#    'hora': 21,
#    'id': '101CO18031721',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.68602},
#   {'_id': '5b8ef752e2705c1932ce62ad',
#    'city': 'Guadalajara',
#    'date': '2018-03-17T22:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-17',
#    'hora': 22,
#    'id': '101CO18031722',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.61301},
#   {'_id': '5b8ef752e2705c1932ce62ae',
#    'city': 'Guadalajara',
#    'date': '2018-03-17T23:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-17',
#    'hora': 23,
#    'id': '101CO18031723',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.47674},
#   {'_id': '5b8ef752e2705c1932ce62af',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T00:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 0,
#    'id': '101CO18031800',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.5264},
#   {'_id': '5b8ef752e2705c1932ce62b0',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T01:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 1,
#    'id': '101CO18031801',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.70402},
#   {'_id': '5b8ef752e2705c1932ce62b1',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T02:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 2,
#    'id': '101CO18031802',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.90412},
#   {'_id': '5b8ef752e2705c1932ce62b2',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T03:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 3,
#    'id': '101CO18031803',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.62915},
#   {'_id': '5b8ef752e2705c1932ce62b3',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T04:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 4,
#    'id': '101CO18031804',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.52372},
#   {'_id': '5b8ef752e2705c1932ce62b4',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T05:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 5,
#    'id': '101CO18031805',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.77863},
#   {'_id': '5b8ef752e2705c1932ce62b5',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T06:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 6,
#    'id': '101CO18031806',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.037},
#   {'_id': '5b8ef752e2705c1932ce62b6',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T07:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 7,
#    'id': '101CO18031807',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.0063},
#   {'_id': '5b8ef752e2705c1932ce62b7',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T08:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 8,
#    'id': '101CO18031808',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 2.5373},
#   {'_id': '5b8ef752e2705c1932ce62b8',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T09:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 9,
#    'id': '101CO18031809',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.372},
#   {'_id': '5b8ef752e2705c1932ce62b9',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T10:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 10,
#    'id': '101CO18031810',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.1013},
#   {'_id': '5b8ef752e2705c1932ce62ba',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T11:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 11,
#    'id': '101CO18031811',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.69831},
#   {'_id': '5b8ef752e2705c1932ce62bb',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T12:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 12,
#    'id': '101CO18031812',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.56567},
#   {'_id': '5b8ef752e2705c1932ce62bc',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T13:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.129Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 13,
#    'id': '101CO18031813',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.42016},
#   {'_id': '5b8ef752e2705c1932ce62bd',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T14:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.131Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 14,
#    'id': '101CO18031814',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.46177},
#   {'_id': '5b8ef752e2705c1932ce62be',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T15:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.131Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 15,
#    'id': '101CO18031815',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.42681},
#   {'_id': '5b8ef752e2705c1932ce62bf',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T16:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.131Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 16,
#    'id': '101CO18031816',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.4354},
#   {'_id': '5b8ef752e2705c1932ce62c0',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T17:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.131Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 17,
#    'id': '101CO18031817',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.4293},
#   {'_id': '5b8ef752e2705c1932ce62c1',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T18:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.131Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 18,
#    'id': '101CO18031818',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.4116},
#   {'_id': '5b8ef752e2705c1932ce62c2',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T19:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.131Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 19,
#    'id': '101CO18031819',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.45009},
#   {'_id': '5b8ef752e2705c1932ce62c3',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T20:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.131Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 20,
#    'id': '101CO18031820',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.51683},
#   {'_id': '5b8ef752e2705c1932ce62c4',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T21:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.131Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 21,
#    'id': '101CO18031821',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.59761},
#   {'_id': '5b8ef752e2705c1932ce62c5',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T22:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.131Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 22,
#    'id': '101CO18031822',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.58439},
#   {'_id': '5b8ef752e2705c1932ce62c6',
#    'city': 'Guadalajara',
#    'date': '2018-03-18T23:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.131Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-18',
#    'hora': 23,
#    'id': '101CO18031823',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.56137},
#   {'_id': '5b8ef752e2705c1932ce62c7',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T00:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.131Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 0,
#    'id': '101CO18031900',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.63216},
#   {'_id': '5b8ef752e2705c1932ce62c8',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T01:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.131Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 1,
#    'id': '101CO18031901',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.69315},
#   {'_id': '5b8ef752e2705c1932ce62c9',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T02:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.131Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 2,
#    'id': '101CO18031902',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.59756},
#   {'_id': '5b8ef752e2705c1932ce62ca',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T03:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 3,
#    'id': '101CO18031903',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.57716},
#   {'_id': '5b8ef752e2705c1932ce62cb',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T04:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 4,
#    'id': '101CO18031904',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.53393},
#   {'_id': '5b8ef752e2705c1932ce62cc',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T05:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 5,
#    'id': '101CO18031905',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.54949},
#   {'_id': '5b8ef752e2705c1932ce62cd',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T06:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 6,
#    'id': '101CO18031906',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.57396},
#   {'_id': '5b8ef752e2705c1932ce62ce',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T07:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 7,
#    'id': '101CO18031907',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.2655},
#   {'_id': '5b8ef752e2705c1932ce62cf',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T08:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 8,
#    'id': '101CO18031908',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.4978},
#   {'_id': '5b8ef752e2705c1932ce62d0',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T09:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 9,
#    'id': '101CO18031909',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.0722},
#   {'_id': '5b8ef752e2705c1932ce62d1',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T10:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 10,
#    'id': '101CO18031910',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 1.031},
#   {'_id': '5b8ef752e2705c1932ce62d2',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T11:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 11,
#    'id': '101CO18031911',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.87384},
#   {'_id': '5b8ef752e2705c1932ce62d3',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T12:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 12,
#    'id': '101CO18031912',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.57433},
#   {'_id': '5b8ef752e2705c1932ce62d4',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T13:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 13,
#    'id': '101CO18031913',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.38611},
#   {'_id': '5b8ef752e2705c1932ce62d5',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T14:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 14,
#    'id': '101CO18031914',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.33216},
#   {'_id': '5b8ef752e2705c1932ce62d6',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T15:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 15,
#    'id': '101CO18031915',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.32257},
#   {'_id': '5b8ef752e2705c1932ce62d7',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T16:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 16,
#    'id': '101CO18031916',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.36081},
#   {'_id': '5b8ef752e2705c1932ce62d8',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T17:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 17,
#    'id': '101CO18031917',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.3146},
#   {'_id': '5b8ef752e2705c1932ce62d9',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T18:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 18,
#    'id': '101CO18031918',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.34982},
#   {'_id': '5b8ef752e2705c1932ce62da',
#    'city': 'Guadalajara',
#    'date': '2018-03-19T19:00:00.000Z',
#    'date-insert': '2018-09-04T21:21:22.132Z',
#    'estacionesid': 101,
#    'fecha': '2018-03-19',
#    'hora': 19,
#    'id': '101CO18031919',
#    'parametro': 'CO',
#    'state': 'Jalisco',
#    'validoorig': 1,
#    'valororig': 0.34392},
#   ...]}

# %%
# Número de registros totales/número de registros por página = Número de páginas que necesitamos
3244192/5000
# Out:
# 648.8384

# %% [markdown]
# ## Obtener jsons

# %%
from tqdm import tqdm_notebook
from pathlib import Path

# Hay 3243971 registros el 4 de septiembre 2018 a las 15:13
for page in tqdm_notebook(range(1 , 650)):
    
    filename = 'page_%i_sinaica_mediciones.json' %page
    filename = '/mediciones_sinaica_json/'+filename
    # Revisamos si el archivo ya existe (suponemos que no hay cambios en la paginación)
    if not Path(filename).is_file():
    if True:
        data_api = client.makeCall('sinaica', {'pageSize':5000, 'page':page})
        with open(filename, 'w') as outfile:
            json.dump(data_api, outfile)
# Out:
# HBox(children=(IntProgress(value=0, max=451), HTML(value='')))
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=199
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=200
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=201
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=202
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=203
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=204
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=205
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=206
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=207
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=208
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=209
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=210
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=211
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=212
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=213
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=214
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=215
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=216
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=217
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=218
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=219
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=220
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=221
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=222
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=223
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=224
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=225
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=226
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=227
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=228
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=229
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=230
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=231
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=232
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=233
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=234
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=235
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=236
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=237
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=238
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=239
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=240
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=241
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=242
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=243
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=244
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=245
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=246
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=247
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=248
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=249
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=250
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=251
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=252
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=253
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=254
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=255
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=256
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=257
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=258
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=259
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=260
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=261
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=262
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=263
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=264
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=265
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=266
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=267
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=268
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=269
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=270
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=271
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=272
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=273
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=274
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=275
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=276
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=277
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=278
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=279
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=280
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=281
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=282
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=283
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=284
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=285
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=286
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=287
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=288
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=289
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=290
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=291
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=292
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=293
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=294
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=295
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=296
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=297
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=298
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=299
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=300
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=301
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=302
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=303
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=304
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=305
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=306
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=307
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=308
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=309
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=310
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=311
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=312
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=313
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=314
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=315
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=316
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=317
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=318
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=319
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=320
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=321
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=322
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=323
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=324
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=325
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=326
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=327
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=328
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=329
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=330
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=331
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=332
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=333
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=334
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=335
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=336
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=337
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=338
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=339
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=340
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=341
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=342
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=343
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=344
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=345
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=346
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=347
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=348
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=349
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=350
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=351
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=352
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=353
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=354
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=355
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=356
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=357
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=358
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=359
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=360
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=361
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=362
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=363
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=364
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=365
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=366
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=367
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=368
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=369
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=370
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=371
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=372
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=373
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=374
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=375
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=376
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=377
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=378
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=379
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=380
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=381
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=382
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=383
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=384
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=385
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=386
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=387
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=388
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=389
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=390
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=391
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=392
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=393
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=394
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=395
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=396
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=397
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=398
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=399
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=400
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=401
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=402
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=403
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=404
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=405
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=406
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=407
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=408
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=409
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=410
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=411
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=412
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=413
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=414
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=415
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=416
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=417
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=418
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=419
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=420
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=421
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=422
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=423
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=424
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=425
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=426
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=427
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=428
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=429
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=430
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=431
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=432
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=433
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=434
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=435
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=436
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=437
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=438
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=439
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=440
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=441
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=442
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=443
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=444
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=445
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=446
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=447
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=448
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=449
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=450
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=451
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=452
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=453
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=454
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=455
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=456
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=457
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=458
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=459
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=460
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=461
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=462
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=463
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=464
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=465
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=466
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=467
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=468
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=469
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=470
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=471
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=472
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=473
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=474
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=475
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=476
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=477
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=478
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=479
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=480
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=481
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=482
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=483
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=484
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=485
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=486
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=487
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=488
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=489
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=490
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=491
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=492
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=493
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=494
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=495
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=496
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=497
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=498
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=499
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=500
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=501
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=502
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=503
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=504
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=505
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=506
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=507
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=508
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=509
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=510
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=511
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=512
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=513
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=514
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=515
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=516
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=517
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=518
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=519
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=520
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=521
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=522
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=523
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=524
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=525
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=526
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=527
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=528
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=529
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=530
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=531
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=532
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=533
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=534
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=535
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=536
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=537
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=538
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=539
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=540
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=541
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=542
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=543
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=544
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=545
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=546
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=547
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=548
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=549
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=550
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=551
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=552
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=553
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=554
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=555
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=556
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=557
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=558
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=559
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=560
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=561
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=562
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=563
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=564
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=565
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=566
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=567
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=568
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=569
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=570
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=571
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=572
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=573
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=574
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=575
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=576
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=577
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=578
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=579
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=580
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=581
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=582
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=583
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=584
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=585
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=586
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=587
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=588
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=589
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=590
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=591
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=592
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=593
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=594
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=595
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=596
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=597
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=598
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=599
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=600
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=601
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=602
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=603
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=604
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=605
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=606
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=607
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=608
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=609
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=610
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=611
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=612
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=613
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=614
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=615
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=616
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=617
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=618
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=619
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=620
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=621
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=622
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=623
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=624
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=625
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=626
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=627
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=628
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=629
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=630
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=631
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=632
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=633
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=634
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=635
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=636
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=637
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=638
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=639
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=640
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=641
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=642
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=643
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=644
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=645
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=646
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=647
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=648
# CALL: https://api.datos.gob.mx/v2/sinaica?pageSize=5000&page=649

# %% [markdown]
# ## Formatear json a csv

# %%
import json
from glob import glob
from joblib import Parallel, delayed

def parse_mediciones_json(json_file):
    "Función auxiliar para convertir los jsons de mediciones de calidad de aire en Pandas Data Frame"
    # Abrimos el archivo json descargado previamente
    with open(json_file, 'r') as aux:
        results = json.load(aux)['results'] # Los resultados vienen en la seccion *results*
    
    # Vamos a guardar los datos de resultados en una lista para después concatenarlos en un DataFrame
    pre_data = []
    
    for r in results:
        # Obtenemos DataFrame previo y lo agregamos
        aux = pd.DataFrame.from_dict(r, orient='index').T
        pre_data.append(aux)
    
    # Concatenamos todos los datos y devolvemos el DataFrame, siempre que haya datos
    if len(pre_data)>0:
        pre_data = pd.concat(pre_data, ignore_index=True)
        return pre_data
    
    # Si por alguna razón no hay datos imprimimos el resultado y no devolvemos nada
    else:
        print('NO DATA FOR ', json_file)
        return

# %%
name = '/sinaica_mediciones_json/page_%i_sinaica_mediciones.json'

c = 1

for i, j in zip([1, 501], [501, 649]):
    print('Chunk', c)
    aux_list = [name %n for n in range(i, j)]

    sinaica_mediciones = Parallel(n_jobs=-1, verbose=8)(delayed (parse_mediciones_json)(f) for f in aux_list)

    sinaica_mediciones = pd.concat(sinaica_mediciones, ignore_index=True)
    print(sinaica_mediciones.shape)
    sinaica_mediciones.to_csv('/mediciones_sinaica_csv/sinaica_mediciones_%i_%i.csv' %(i, j),
                              index=False)
    c+=1
# Out:
# Chunk 1
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:   45.3s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:  4.0min finished
# (2500000, 12)
# Chunk 2
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:   50.2s
# [Parallel(n_jobs=-1)]: Done 148 out of 148 | elapsed:  1.2min finished
# (740000, 12)

# %%
all_data_mediciones = []
for file in glob('/mediciones_sinaica_csv/*.csv'):
    aux = pd.read_csv(file,
                      usecols = ['estacionesid', 'fecha', 'hora', 'city', 'state',
                                 'parametro', 'valororig', 'validoorig'])
    all_data_mediciones.append(aux)
    
all_data_mediciones = pd.concat(all_data_mediciones)
print(all_data_mediciones.shape)
all_data_mediciones.head()
# Out:
# (3240000, 8)
#       city  estacionesid       fecha  hora parametro    state  validoorig  \
# 0  Durango            58  2018-08-01    13      PM10  Durango           1
# 1  Durango            58  2018-08-01    14      PM10  Durango           1
# 2  Durango            58  2018-08-01    15      PM10  Durango           1
# 3  Durango            58  2018-08-01    16      PM10  Durango           1
# 4  Durango            58  2018-08-01    17      PM10  Durango           1
#
#    valororig
# 0     988.61
# 1     988.61
# 2     988.60
# 3     988.63
# 4     988.63

# %%
all_data_mediciones.estacionesid.nunique()
# Out:
# 123

# %%
all_data_mediciones.hora.value_counts()
# Out:
# 9     140201
# 10    140097
# 8     139461
# 11    139188
# 17    139004
# 18    138913
# 16    138733
# 19    138639
# 20    138600
# 12    138533
# 15    138433
# 13    138380
# 21    138138
# 14    137879
# 22    137833
# 7     137731
# 6     136910
# 5     136227
# 4     132581
# 3     131681
# 2     124890
# 0     122954
# 23    119612
# 1     115382
# Name: hora, dtype: int64

# %%
# all_data_mediciones.to_csv('/data_mediciones_todas_estaciones.csv', index=False)
